# %%
import subprocess, os
os.chdir('/task/app')
res = subprocess.run(['/bin/sh', '-lc', 'yarn coverage'], capture_output=True, text=True)
print('RETURN', res.returncode)
print('STDOUT:\n', res.stdout)
print('STDERR:\n', res.stderr)
