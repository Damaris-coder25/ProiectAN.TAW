# %%
import subprocess, os, textwrap
os.chdir('/task/app')
cmd = 'npx vitest run src/vue-components.test.js --reporter=dot'
res = subprocess.run(['sh','-lc',cmd], capture_output=True, text=True, timeout=1200)
print('RC=', res.returncode)
print('STDOUT:\n', res.stdout)
print('STDERR:\n', res.stderr)
